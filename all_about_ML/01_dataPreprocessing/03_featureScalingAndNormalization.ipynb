# %% [markdown]
# # **<center><span style= "color:#2F539B;">Feature scaling and normalization</span></center>**

# %% [markdown]
# ## ***<span style= "color:maroon;">Ways to impute outliers </span>***
# - ***`Z score method`***
# - **`IQR method`**
# - **`Kmeans clustering`**

# %% [markdown]
# ## ***<span style= "color:purple;">Imports </span>***

# %% [markdown]
# ### ***<span style= "color:#85BB65;"> Using Kmeans clustering</span>***
